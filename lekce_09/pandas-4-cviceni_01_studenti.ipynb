# %% [markdown]
# Studenti
# zapni hlavu
# Stáhni si datové sety, se kterými budeme pracovat v tomto cvičení: jmena.csv, studenti1.csv, studenti2.csv.

# %%
import pandas

jmena = pandas.read_csv("https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/excs/excs>studenti/jmena.csv")
s1 = pandas.read_csv("https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/excs/excs>studenti/studenti1.csv")
s2 = pandas.read_csv("https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/excs/excs>studenti/studenti2.csv")

# %% [markdown]
# První set už známe z minulé lekce. Druhé dva sety obsahují seznam studentů na nějaké menší IT fakultě. Pozor, tato data nemají žádnou souvislost s výsledky maturity, které jsme procházeli během lekce.
#
# Proveď následující úkoly a zodpověz předložené otázky.
#
# Načti dva datové sety studentů do oddělených pandas DataFrame a pomocí funkce concat je spoj do jednoho setu.

# %%
studenti = pandas.concat([s1, s2])
studenti
# studenti.info()
# Out:
#        jméno      příjmení                      obor  ročník  kruh  prospěch
# 0    Ludmila    Šindlerová  informatika a management     4.0  11.0      2.49
# 1        Jan       Pekárek    softwarové inženýrství     1.0   7.0      1.05
# 2      Milan         Weiss        počítačová grafika     5.0  11.0      2.62
# 3     Jiřina       Petrová         správa IT systémů     4.0   1.0      1.15
# 4      Josef      Navrátil        číslicová technika     5.0   7.0      2.42
# ..       ...           ...                       ...     ...   ...       ...
# 135   Daniel  Brandstätter  informatika a management     4.0   2.0      2.05
# 136    Lukáš          Čech  informatika a management     5.0   NaN      1.59
# 137   Dagmar      Košanová    teoretická informatika     5.0  10.0      1.34
# 138    Ivana    Macháčková        webové inženýrství     1.0   NaN      2.92
# 139  Martina       Turková    softwarové inženýrství     5.0   8.0      1.54
#
# [345 rows x 6 columns]

# %% [markdown]
# Pokud studentovi chybí ročník, znamená to, že již nestuduje. Pokud mu chybí číslo skupiny, znamená to, že jde o dálkového studenta. Kolik studentů v datovém setu již nestuduje a kolik jsou dálkoví studenti?

# %%
studenti[studenti["ročník"].isnull()]
# Out:
#          jméno     příjmení                      obor  ročník  kruh  prospěch
# 6         Anna  Pavloušková        počítačová grafika     NaN  12.0      2.66
# 13       Alena      Krajová    softwarové inženýrství     NaN   7.0      1.64
# 33      Ondřej         Cicu        počítačová grafika     NaN   1.0      2.18
# 38      Václav       Straka        počítačová grafika     NaN   NaN      2.36
# 45      Michal      Linhart    softwarové inženýrství     NaN   9.0      2.20
# 64      Libuše    Šterclová        webové inženýrství     NaN  12.0      1.93
# 77    Miroslav        Smrek        počítačová grafika     NaN   2.0      1.86
# 89        Petr        Dobeš    softwarové inženýrství     NaN  12.0      1.47
# 96    Kateřina     Křivková  informatika a management     NaN   6.0      2.88
# 110      Pavel         Nový        webové inženýrství     NaN   1.0      2.37
# 124      David         Šikl        počítačová grafika     NaN  10.0      1.20
# 146       Jiří        Zeman  informatika a management     NaN  12.0      2.28
# 185     Eliška       Řípová         správa IT systémů     NaN   NaN      1.39
# 189      Pavla     Plhalová         správa IT systémů     NaN   9.0      1.43
# 194      David      Ševeček  informatika a management     NaN   1.0      2.88
# 203      Radek     Chrástek        číslicová technika     NaN   2.0      2.00
# 204     Blanka      Koubová        počítačová grafika     NaN   5.0      2.05
# 4      Jarmila      Selucká  informatika a management     NaN   6.0      2.34
# 7    Stanislav       Veselý  informatika a management     NaN   5.0      2.48
# 26       Irena     Štavková        webové inženýrství     NaN   5.0      1.67
# 29       Šárka     Šustrová        číslicová technika     NaN   6.0      2.01
# 41      Blanka       Dubová    softwarové inženýrství     NaN   1.0      2.91
# 43      Václav       Hrabec    teoretická informatika     NaN   6.0      2.72
# 54     Martina  Zámečníková        číslicová technika     NaN   6.0      2.24
# 58      Zuzana    Dvořáková        webové inženýrství     NaN  10.0      3.00
# 67    Miloslav        Vozka        webové inženýrství     NaN   9.0      2.21
# 78        Jiří      Jelínek        webové inženýrství     NaN   7.0      2.87
# 91       Libor        Boček  informatika a management     NaN   9.0      1.72
# 111      Jitka       Zíková    softwarové inženýrství     NaN   7.0      2.98
# 113     Renata     Vrkočová        číslicová technika     NaN   3.0      1.74
# 115   Miroslav      Růžička        webové inženýrství     NaN   7.0      1.37
# 123    Barbora      Surmová         správa IT systémů     NaN  12.0      2.61
# 126      Radek       Svatoš        počítačová grafika     NaN   1.0      2.85

# %%
studenti[studenti["kruh"].isnull()]
# Out:
#         jméno    příjmení                      obor  ročník  kruh  prospěch
# 26   Jaroslav       Honza        číslicová technika     2.0   NaN      2.54
# 31     Zdeněk       Horák        číslicová technika     2.0   NaN      2.63
# 38     Václav      Straka        počítačová grafika     NaN   NaN      2.36
# 57     Monika  Doležalová         správa IT systémů     5.0   NaN      1.27
# 65    Natálie   Petříková        webové inženýrství     5.0   NaN      2.99
# 73        Jan        Póda        číslicová technika     2.0   NaN      2.33
# 76     Martin       Lupač        webové inženýrství     4.0   NaN      1.50
# 90       Jiří      Karban        počítačová grafika     2.0   NaN      1.89
# 103     Lukáš     Jarůšek        počítačová grafika     2.0   NaN      2.09
# 107     Roman     Marinec         správa IT systémů     2.0   NaN      2.14
# 136     Lucie      Dudová        číslicová technika     3.0   NaN      2.15
# 160      Věra    Sýkorová         správa IT systémů     2.0   NaN      1.71
# 185    Eliška      Řípová         správa IT systémů     NaN   NaN      1.39
# 188     Jakub       Kodet        číslicová technika     2.0   NaN      1.83
# 202    Daniel      Rezler        počítačová grafika     4.0   NaN      2.97
# 6       Petra    Šlégrová        číslicová technika     3.0   NaN      2.71
# 21        Jan        Hajs         správa IT systémů     1.0   NaN      1.58
# 33     Dagmar    Musilová        počítačová grafika     5.0   NaN      1.31
# 44       Věra   Kopperová  informatika a management     5.0   NaN      2.51
# 55   Veronika   Fieberová    teoretická informatika     1.0   NaN      2.18
# 71      Pavel        Miko        počítačová grafika     4.0   NaN      2.26
# 81       Aleš        Král        číslicová technika     4.0   NaN      2.18
# 93      Marie    Koděrová        počítačová grafika     4.0   NaN      2.12
# 106   Ludmila  Adamčíková    softwarové inženýrství     2.0   NaN      1.31
# 125     Lenka   Svobodová    teoretická informatika     4.0   NaN      1.72
# 136     Lukáš        Čech  informatika a management     5.0   NaN      1.59
# 138     Ivana  Macháčková        webové inženýrství     1.0   NaN      2.92

# %% [markdown]
# Vyčisti data od studentů, kteří nestudují nebo studují jen dálkově. Nadále budeme pracovat pouze s prezenčními studenty.

# %%
studenti_prez = studenti.dropna(subset=["ročník", "kruh"])
studenti_prez
# Out:
#        jméno      příjmení                      obor  ročník  kruh  prospěch
# 0    Ludmila    Šindlerová  informatika a management     4.0  11.0      2.49
# 1        Jan       Pekárek    softwarové inženýrství     1.0   7.0      1.05
# 2      Milan         Weiss        počítačová grafika     5.0  11.0      2.62
# 3     Jiřina       Petrová         správa IT systémů     4.0   1.0      1.15
# 4      Josef      Navrátil        číslicová technika     5.0   7.0      2.42
# ..       ...           ...                       ...     ...   ...       ...
# 133    Klára     Valentová         správa IT systémů     1.0  11.0      1.10
# 134    Pavla     Veverková        počítačová grafika     4.0   6.0      2.98
# 135   Daniel  Brandstätter  informatika a management     4.0   2.0      2.05
# 137   Dagmar      Košanová    teoretická informatika     5.0  10.0      1.34
# 139  Martina       Turková    softwarové inženýrství     5.0   8.0      1.54
#
# [287 rows x 6 columns]
